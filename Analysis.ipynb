# %%
import numpy as np
import matplotlib.pyplot as plt
with open("figures/training_log.txt") as f:
    lines = list(f.readlines())
    
with open("figures/train_beginning.txt") as f:
    lines2 = list(f.readlines())

# %%
outputs = lines[2::4]
outputs_s = lines2[2::4]

# %%
val_losses = [float(l.split("val_loss: ")[1]) for l in outputs]
val_preq = [float(l.split("val_loss: ")[1]) for l in lines2 if "val_" in l]

# %%
plt.plot(np.arange(len(val_losses) + len(val_preq)) * 2010, np.concatenate([val_preq, val_losses]), label="Validation Loss")
plt.plot(np.arange(len(val_losses) + len(val_preq)) * 2010, np.concatenate([train_preq, train_losses]), label="Train Loss")
plt.xlabel("Samples")
plt.legend()

# %%
np.arange(len(val_losses) + len(val_preq)) * 2010
# Out:
# array([      0,    2010,    4020, ..., 7075200, 7077210, 7079220])

# %%
train_losses = [float(l.split()[4]) for l in outputs]
train_preq = [float(l.split()[4]) for l in lines2 if "val_" in l]

# %%
min(val_losses)
# Out:
# 0.7426
