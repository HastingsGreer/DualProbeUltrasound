# %%
import os
import pickle
import numpy as np
import tensorflow.keras as keras
data_dir = "prepped_data/train/"
# Out:
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/hastings/anaconda3/envs/stylegan/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
names = os.listdir(data_dir)

# %%
classes.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-27d42acfe7bd> in <module>
# ----> 1 classes.shape
#
# NameError: name 'classes' is not defined

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', 
                 input_shape=(128, 128, 4)
                 
                ))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))              
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(12))

model.summary()

model.compile(loss=keras.losses.mean_squared_error,
              optimizer=Adam(lr=.0002))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      1184
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# flatten (Flatten)            (None, 25600)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               13107712
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                6156
# =================================================================
# Total params: 13,802,156
# Trainable params: 13,802,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
name = names[0]

def load_dataset(name):
    with open(name, "rb") as f:
        dataset = pickle.load(f)

    data = []
    classes = []
    for elem in dataset:
        data_entry = np.array(np.stack(elem["data"], axis=-1), dtype=np.float32)
        data_entry += 1000
        data_entry /= 2000
        data.append(data_entry)

        class_entry = elem["classes"]
        class_entry = np.concatenate([class_entry[0] / 4, class_entry[1].flatten() * 40])
        class_entry[[3, 7, 11]] -= 40
        classes.append(class_entry)
    data = np.array(data)
    classes = np.array(classes)
    return data, classes

# %%
tdata, tclasses = load_dataset("prepped_data/test/Pancreas_6pregenerated.pickle")
import random
for _ in range(20):
    print("===========")
    random.shuffle(names)
    for name in names:
        print(name)
        data, classes = load_dataset(data_dir + name)
        loss_curve = model.fit(data, 
              classes,
              batch_size=256,
              epochs=1,
              verbose=1,
              validation_data=(tdata[:256], tclasses[:256]))
# Out:
# ===========
# Pancreas_65pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 8s 933us/step - loss: 1.8415 - val_loss: 1.7779
# Pancreas_44pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 505us/step - loss: 1.5720 - val_loss: 1.5325
# Pancreas_36pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 503us/step - loss: 1.4091 - val_loss: 1.3753
# Pancreas_60pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 503us/step - loss: 1.3642 - val_loss: 1.3221
# Pancreas_74pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 504us/step - loss: 1.2781 - val_loss: 1.1889
# Pancreas_20pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 505us/step - loss: 1.1539 - val_loss: 1.1129
# Pancreas_46pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 505us/step - loss: 1.1297 - val_loss: 1.0522
# Pancreas_31pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.3196 - val_loss: 1.1156
# Pancreas_45pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.1141 - val_loss: 1.0955
# Pancreas_62pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0314 - val_loss: 0.9930
# Pancreas_43pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0401 - val_loss: 0.9602
# Pancreas_70pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 505us/step - loss: 1.0976 - val_loss: 0.9475
# Pancreas_42pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0348 - val_loss: 0.9687
# Pancreas_40pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9927 - val_loss: 1.0291
# Pancreas_54pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0116 - val_loss: 0.9131
# Pancreas_29pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0850 - val_loss: 0.9300
# Pancreas_30pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9486 - val_loss: 0.9305
# Pancreas_26pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.9987 - val_loss: 0.9117
# Pancreas_37pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9453 - val_loss: 0.9153
# Pancreas_48pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9345 - val_loss: 0.9029
# Pancreas_47pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 1.0055 - val_loss: 0.8957
# Pancreas_33pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.9661 - val_loss: 0.8706
# Pancreas_38pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.9523 - val_loss: 0.8566
# Pancreas_67pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9060 - val_loss: 0.8205
# Pancreas_64pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9178 - val_loss: 0.8844
# Pancreas_34pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9158 - val_loss: 0.8942
# Pancreas_76pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9726 - val_loss: 0.9071
# Pancreas_32pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8477 - val_loss: 0.8843
# Pancreas_59pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8061 - val_loss: 0.8852
# Pancreas_50pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9169 - val_loss: 0.8922
# Pancreas_72pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8309 - val_loss: 0.8514
# Pancreas_17pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8359 - val_loss: 0.8449
# Pancreas_23pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 506us/step - loss: 1.0622 - val_loss: 0.8240
# Pancreas_58pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8958 - val_loss: 0.8329
# Pancreas_66pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.8965 - val_loss: 0.8437
# Pancreas_19pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.8888 - val_loss: 0.8721
# Pancreas_51pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8232 - val_loss: 0.8219
# Pancreas_57pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8412 - val_loss: 0.8002
# Pancreas_78pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9266 - val_loss: 0.8069
# Pancreas_77pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.8292 - val_loss: 0.8184
# Pancreas_24pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8522 - val_loss: 0.8100
# Pancreas_16pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7732 - val_loss: 0.8248
# Pancreas_28pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.9259 - val_loss: 0.8024
# Pancreas_68pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.9082 - val_loss: 0.8317
# Pancreas_27pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8497 - val_loss: 0.7856
# Pancreas_61pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8160 - val_loss: 0.8368
# Pancreas_39pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8929 - val_loss: 0.8338
# Pancreas_79pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9051 - val_loss: 0.8029
# Pancreas_22pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8414 - val_loss: 0.8118
# Pancreas_25pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8742 - val_loss: 0.7835
# Pancreas_56pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8845 - val_loss: 0.7969
# Pancreas_75pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7978 - val_loss: 0.8306
# Pancreas_21pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8088 - val_loss: 0.7501
# Pancreas_73pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7608 - val_loss: 0.7611
# Pancreas_80pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8197 - val_loss: 0.7728
# Pancreas_52pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 510us/step - loss: 0.7509 - val_loss: 0.7816
# Pancreas_41pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7377 - val_loss: 0.7834
# Pancreas_18pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7618 - val_loss: 0.7942
# Pancreas_55pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7570 - val_loss: 0.7758
# Pancreas_71pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7654 - val_loss: 0.7494
# Pancreas_14pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9624 - val_loss: 0.8333
# Pancreas_15pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7497 - val_loss: 0.8010
# Pancreas_63pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7227 - val_loss: 0.8522
# Pancreas_81pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6964 - val_loss: 0.7774
# Pancreas_35pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7575 - val_loss: 0.7594
# Pancreas_53pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7644 - val_loss: 0.7539
# Pancreas_69pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.7768 - val_loss: 0.7565
# Pancreas_49pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8467 - val_loss: 0.7502
# ===========
# Pancreas_77pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7639 - val_loss: 0.7647
# Pancreas_57pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7576 - val_loss: 0.7411
# Pancreas_63pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.6884 - val_loss: 0.8273
# Pancreas_44pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7647 - val_loss: 0.7626
# Pancreas_47pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8056 - val_loss: 0.7946
# Pancreas_70pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7943 - val_loss: 0.7539
# Pancreas_19pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8109 - val_loss: 0.7758
# Pancreas_55pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7243 - val_loss: 0.7693
# Pancreas_62pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7373 - val_loss: 0.7693
# Pancreas_43pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7365 - val_loss: 0.7375
# Pancreas_41pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.6915 - val_loss: 0.7943
# Pancreas_22pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7737 - val_loss: 0.7463
# Pancreas_58pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7697 - val_loss: 0.7664
# Pancreas_46pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7131 - val_loss: 0.7483
# Pancreas_75pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7535 - val_loss: 0.7694
# Pancreas_17pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.7239 - val_loss: 0.7334
# Pancreas_26pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7978 - val_loss: 0.7666
# Pancreas_23pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.9138 - val_loss: 0.7035
# Pancreas_38pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7651 - val_loss: 0.7511
# Pancreas_79pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8172 - val_loss: 0.7501
# Pancreas_18pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7163 - val_loss: 0.7589
# Pancreas_74pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7167 - val_loss: 0.6961
# Pancreas_54pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8142 - val_loss: 0.7224
# Pancreas_52pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6641 - val_loss: 0.7586
# Pancreas_72pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.6854 - val_loss: 0.7490
# Pancreas_67pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7188 - val_loss: 0.7060
# Pancreas_64pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7510 - val_loss: 0.7252
# Pancreas_28pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8300 - val_loss: 0.7192
# Pancreas_32pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7164 - val_loss: 0.7416
# Pancreas_27pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7287 - val_loss: 0.7126
# Pancreas_60pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6795 - val_loss: 0.7327
# Pancreas_81pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.6452 - val_loss: 0.7099
# Pancreas_76pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.8469 - val_loss: 0.8014
# Pancreas_71pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6888 - val_loss: 0.7226
# Pancreas_69pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7248 - val_loss: 0.7288
# Pancreas_49pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7762 - val_loss: 0.7819
# Pancreas_56pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.8090 - val_loss: 0.7455
# Pancreas_40pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7349 - val_loss: 0.7519
# Pancreas_80pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7209 - val_loss: 0.6914
# Pancreas_15pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6480 - val_loss: 0.7957
# Pancreas_14pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.9000 - val_loss: 0.7391
# Pancreas_20pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7247 - val_loss: 0.7317
# Pancreas_66pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7341 - val_loss: 0.7427
# Pancreas_31pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.8122 - val_loss: 0.7554
# Pancreas_21pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6959 - val_loss: 0.7202
# Pancreas_78pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7919 - val_loss: 0.7140
# Pancreas_37pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.7373 - val_loss: 0.7342
# Pancreas_30pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 509us/step - loss: 0.7350 - val_loss: 0.7587
# Pancreas_29pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 507us/step - loss: 0.7709 - val_loss: 0.7259
# Pancreas_16pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.6626 - val_loss: 0.7483
# Pancreas_68pregenerated.pickle
# Train on 8192 samples, validate on 256 samples
# Epoch 1/1
# 8192/8192 [==============================] - 4s 508us/step - loss: 0.7787 - val_loss: 0.7706
# Pancreas_50pregenerated.pickle

# %%
model.compile(loss=keras.losses.mean_squared_error,
              optimizer=Adam(lr=.0002))

# %%
rclasses = model.predict(tdata)

# %%
data.size
# Out:
# 536870912

# %%
tclasses[0]
# Out:
# array([ 0.3781468 ,  5.0856459 ,  1.09619544, -0.0160148 ,  0.76078398,
#         0.83793504, -0.74443662, -0.01456173, -0.78137099, -0.85249136,
#         0.76546342, -0.01641181])

# %%
import matplotlib.pyplot as plt
for j in range(12):
    plt.scatter(rclasses[:, j], tclasses[:, j], s=.1)
    plt.show()

# %%
#model.save("naive_network_weights")

# %%
import matplotlib

# %%
plt.scatter?
# Out:
# Object `plt.scatter` not found.

# %%
import tensorflow
tensorflow.test.is_gpu_available()
# Out:
# True

# %%
import tensorflow as tf
with tf.Session() as sess:
    devices = sess.list_devices()

# %%
import sys
sys.executable
# Out:
# '/home/hastings/anaconda3/envs/stylegan/bin/python'
